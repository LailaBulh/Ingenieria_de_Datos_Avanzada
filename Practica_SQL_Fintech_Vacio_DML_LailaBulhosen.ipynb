# %% [markdown]
# <a href="https://colab.research.google.com/github/LailaBulh/Ingenieria_de_Datos_Avanzada/blob/main/Practica_SQL_Fintech_Vacio_DML_LailaBulhosen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📘 Práctica SQL – Fintech Databank
#
# **Nombre:** Laila Montserrat Bulhosen Ramos
#
# **Matricula:** 263166
#
# **Link Github:**[Práctica_SQL–Fintech_Databank](https://github.com/LailaBulh/Ingenieria_de_Datos_Avanzada/blob/main/Practica_SQL_Fintech_Vacio_DML_LailaBulhosen.ipynb)
#
#
# Este notebook contiene los **ejercicios prácticos** sobre la base de datos `fintech_databank.db`.
# Tu objetivo será escribir consultas SQL para resolver cada problema.
#
# 👉 **Recuerda:** conecta la base de datos antes de empezar:
# ```python
# %sql sqlite:////content/drive/MyDrive/ClassFilesIDA/fintech_databank.db
# ```

# %%
# Montar el drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 🔹 Instrucciones generales
# 1. Conéctate a la base de datos.
# 2. Antes de cada ejercicio, revisa las tablas disponibles con:
#    ```sql
#    %%sql
#    SELECT name FROM sqlite_master WHERE type='table';
#    ```
# 3. Ejecuta tus consultas SQL en las celdas de código marcadas como `%%sql`.
# 4. Guarda tus respuestas en este notebook.

# %% [markdown]
# ## **Instalación de bibliotecas externas**

# %%
# Comando para instalar una biblioteca externa
# !pip install sqlalchemy

# %%
# Ejecuta esta línea de código y se empezará a instalar
# !pip install sqlalchemy

# %%
# Instrucción para instalar ipyhon-sql
# !pip install ipython-sql
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 20.0 MB/s eta 0:00:00
# ...

# %%
# Instrucción para instalar ipyhon-sql
# !pip install ipython-sql

# %%
# !pip install ipython-sql

# %% [markdown]
# ## **Carga y conexión de la base de datos**

# %%
# %load_ext nombre_extension
# %load_ext sql

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'

### Conectar Colab con archivo de la base de datos
# %sql sqlite:////content/drive/MyDrive/ClassFilesIDA/fintech_databank.db

# %% [markdown]
# ## **Ejercicio 1. Exploración básica**

# %% [markdown]
# - Lista todas las filas de la tabla **clientes**.
# - Muestra únicamente el nombre y la ciudad de cada cliente.
# - ¿Cuántos clientes hay en total?

# %%
### Revisar tablas disponibles
# %%sql SELECT name FROM sqlite_master WHERE type='table';
# Out:
#  * sqlite:////content/drive/MyDrive/ClassFilesIDA/fintech_databank.db
# Done.
# [('clientes',), ('cuentas',), ('transacciones',), ('tipos_cambio',)]

# %%
### Filas totales de tabla clientes
# %%sql SELECT * FROM clientes;
# Out:
#  * sqlite:////content/drive/MyDrive/ClassFilesIDA/fintech_databank.db
# Done.
# [('C001', 'Ana Torres', 'CDMX', 'Retail'),
#  ('C002', 'Luis Gómez', 'Guadalajara', 'Retail'),
#  ('C003', 'Textiles J&R', 'Monterrey', 'PYME')]

# %%
### Nombre y ciudad de cada cliente
# %%sql SELECT nombre ,ciudad FROM clientes;
# Out:
#  * sqlite:////content/drive/MyDrive/ClassFilesIDA/fintech_databank.db
# Done.
# [('Ana Torres', 'CDMX'),
#  ('Luis Gómez', 'Guadalajara'),
#  ('Textiles J&R', 'Monterrey')]

# %%
### Total de clientes
# %%sql SELECT COUNT(DISTINCT nombre) AS total_clients FROM clientes;
# Out:
#  * sqlite:////content/drive/MyDrive/ClassFilesIDA/fintech_databank.db
# Done.
# [(3,)]

# %% [markdown]
# ## **Ejercicio 2. Cuentas de clientes**

# %% [markdown]
# - Obtén todas las cuentas del cliente **C001**.
# - Lista las cuentas que están en moneda **USD**.
# - Muestra el número de cuentas que tiene cada cliente (usa `GROUP BY`).

# %%
### Cuentas del cliente C001
# %%sql SELECT * FROM cuentas WHERE cliente_id = 'C001';
# Out:
#  * sqlite:////content/drive/MyDrive/ClassFilesIDA/fintech_databank.db
# Done.
# [('A1001', 'C001', 'MXN', 'Vista', '2024-11-10'),
#  ('A1002', 'C001', 'USD', 'Ahorro', '2024-12-01')]

# %%
### Cuentas en USD
# %%sql SELECT * FROM cuentas WHERE moneda = 'USD';
# Out:
#  * sqlite:////content/drive/MyDrive/ClassFilesIDA/fintech_databank.db
# Done.
# [('A1002', 'C001', 'USD', 'Ahorro', '2024-12-01')]

# %%
### Cuentas por cliente
# %%sql SELECT cliente_id ,COUNT(cuenta_id) cuentas_cliente FROM cuentas GROUP BY cliente_id;
# Out:
#  * sqlite:////content/drive/MyDrive/ClassFilesIDA/fintech_databank.db
# Done.
# [('C001', 2), ('C002', 1), ('C003', 1)]

# %% [markdown]
# ## **Ejercicio 3. Transacciones**

# %% [markdown]
# - Obtén todas las transacciones de la cuenta **A1001**.
# - Calcula el **saldo neto** de esa cuenta sumando la columna `monto`.
# - Lista las transacciones que sean **comisiones**.

# %%
### Transacciones de la cuednta A1001
# %%sql SELECT cuenta_id ,COUNT(tx_id) AS transactions FROM transacciones WHERE cuenta_id = 'A1001';
# Out:
#  * sqlite:////content/drive/MyDrive/ClassFilesIDA/fintech_databank.db
# Done.
# [('A1001', 4)]

# %%
# %%sql SELECT * FROM transacciones WHERE cuenta_id = 'A1001';
# Out:
#  * sqlite:////content/drive/MyDrive/ClassFilesIDA/fintech_databank.db
# Done.
# [('T0001', 'A1001', '2025-07-01', 'Nómina', 25000, 'Depósito'),
#  ('T0002', 'A1001', '2025-07-03', 'Renta', -12000, 'Pago'),
#  ('T0003', 'A1001', '2025-07-05', 'Super', -2200, 'Pago'),
#  ('T0009', 'A1001', '2025-07-15', 'Comisión retiro', -35, 'Comisión')]

# %%
### Saldo neto de cuenta A1001
# %%sql SELECT cuenta_id ,SUM(monto) AS saldo_neto FROM transacciones WHERE cuenta_id = 'A1001';
# Out:
#  * sqlite:////content/drive/MyDrive/ClassFilesIDA/fintech_databank.db
# Done.
# [('A1001', 10765)]

# %%
###Transacciones tipo Comisión
# %%sql SELECT * FROM transacciones WHERE categoria = 'Comisión';
# Out:
#  * sqlite:////content/drive/MyDrive/ClassFilesIDA/fintech_databank.db
# Done.
# [('T0006', 'A2001', '2025-07-04', 'Comisión manejo', -45, 'Comisión'),
#  ('T0009', 'A1001', '2025-07-15', 'Comisión retiro', -35, 'Comisión')]

# %% [markdown]
# ## **Ejercicio 4. Reportes con agrupaciones**

# %% [markdown]
# - Calcula el total de transacciones (suma de `monto`) por **categoría**.

# %%
### Total de monto por categoria
# %%sql SELECT categoria ,SUM(monto) AS monto FROM transacciones GROUP BY categoria;
# Out:
#  * sqlite:////content/drive/MyDrive/ClassFilesIDA/fintech_databank.db
# Done.
# [('Comisión', -80),
#  ('Depósito', 25800),
#  ('Interés', 123.5),
#  ('Pago', -82200),
#  ('Transferencia', 95000)]

# %% [markdown]
# ## **Ejercicio 5. Modificar datos (UPDATE)**
#
# > **Objetivo:** actualizar valores existentes usando `WHERE` de forma segura.
#
# 1. Cambia el `segmento` del cliente **C002** de *Retail* a **PYME**.
# 2. Corrige la `ciudad` de **Textiles J&R (C003)** a **Saltillo**.
#
#
# > **Tip:** siempre valida primero con un `SELECT` y después aplica el `UPDATE`.

# %%
### Revision de tabla
# %%sql SELECT * FROM clientes;
# Out:
#  * sqlite:////content/drive/MyDrive/ClassFilesIDA/fintech_databank.db
# Done.
# [('C001', 'Ana Torres', 'CDMX', 'Retail'),
#  ('C002', 'Luis Gómez', 'Guadalajara', 'PYME'),
#  ('C003', 'Textiles J&R', 'Monterrey', 'PYME')]

# %%
### update en columna segmento del cliente C0002
# %%sql UPDATE clientes SET segmento = 'PYME' WHERE cliente_id = 'C002';
# Out:
#  * sqlite:////content/drive/MyDrive/ClassFilesIDA/fintech_databank.db
# 1 rows affected.
# []

# %%
### Update en ciudad de Textiles J&R
# %%sql UPDATE clientes SET ciudad = 'Saltillo' WHERE nombre = 'Textiles J&R';
# Out:
#  * sqlite:////content/drive/MyDrive/ClassFilesIDA/fintech_databank.db
# 1 rows affected.
# []

# %%
### Comprobación de cambio
# %%sql SELECT * FROM clientes;
# Out:
#  * sqlite:////content/drive/MyDrive/ClassFilesIDA/fintech_databank.db
# Done.
# [('C001', 'Ana Torres', 'CDMX', 'Retail'),
#  ('C002', 'Luis Gómez', 'Guadalajara', 'PYME'),
#  ('C003', 'Textiles J&R', 'Saltillo', 'PYME')]

# %% [markdown]
# ## **Ejercicio 6. Borrar datos (DELETE)**
#
# > **Objetivo:** eliminar filas específicas manteniendo la integridad y usando `WHERE`.
#
# 1. Elimina **solo** las transacciones de la cuenta **A3001** del día **2025-07-12**.
# 2. Elimina la **comisión** de `A2001` del **2025-07-04**.
# > **Tip:** prueba primero con `SELECT` para verificar el subconjunto a borrar.

# %%
### Revision de tabla para cuenta_id A3001
# %%sql SELECT * FROM transacciones WHERE cuenta_id = 'A3001';
# Out:
#  * sqlite:////content/drive/MyDrive/ClassFilesIDA/fintech_databank.db
# Done.
# [('T0007', 'A3001', '2025-07-10', 'Pago nómina empleados', -68000, 'Pago'),
#  ('T0008', 'A3001', '2025-07-12', 'Transferencia cliente', 95000, 'Transferencia')]

# %%
### Eliminar registro de cuenta A3001 en fecha 2025-07-12
# %%sql DELETE FROM transacciones WHERE cuenta_id = 'A3001' AND fecha = '2025-07-12';
# Out:
#  * sqlite:////content/drive/MyDrive/ClassFilesIDA/fintech_databank.db
# 1 rows affected.
# []

# %%
### Revisión de tabla  para cuenta_id A2001
# %%sql SELECT * FROM transacciones WHERE cuenta_id = 'A2001';
# Out:
#  * sqlite:////content/drive/MyDrive/ClassFilesIDA/fintech_databank.db
# Done.
# [('T0005', 'A2001', '2025-07-02', 'Interés mensual', 120, 'Interés'),
#  ('T0006', 'A2001', '2025-07-04', 'Comisión manejo', -45, 'Comisión')]

# %%
### Eliminar registro de cuenta A2001 en fecha 2025-07-04
# %%sql DELETE FROM transacciones WHERE cuenta_id = 'A2001' AND fecha = '2025-07-04';
# Out:
#  * sqlite:////content/drive/MyDrive/ClassFilesIDA/fintech_databank.db
# 1 rows affected.
# []

# %%
### Comprobación de cambios
# %%sql SELECT * FROM transacciones WHERE cuenta_id IN ('A3001', 'A2001');
# Out:
#  * sqlite:////content/drive/MyDrive/ClassFilesIDA/fintech_databank.db
# Done.
# [('T0005', 'A2001', '2025-07-02', 'Interés mensual', 120, 'Interés'),
#  ('T0007', 'A3001', '2025-07-10', 'Pago nómina empleados', -68000, 'Pago')]
